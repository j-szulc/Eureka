# %% [markdown]
# ## Setup:
#
# Run `bash install.sh` inside `/notebooks/installation/` and just accept everything.

# %% [markdown]
# ## "Proof" that IsaacGymEnv works:

# %%
! cd /tmp && micromamba run -n eureka python -m isaacgymenvs.train task=Cartpole
# Out:
# warning  libmamba 'root_prefix' set with default value: /root/micromamba
# Importing module 'gym_38' (/notebooks/isaacgym/python/isaacgym/_bindings/linux-x86_64/gym_38.so)
# Setting GYM_USD_PLUG_INFO_PATH to /notebooks/isaacgym/python/isaacgym/_bindings/linux-x86_64/usd/plugInfo.json
# PyTorch version 2.0.0+cu117
# Device count 1
# /notebooks/isaacgym/python/isaacgym/_bindings/src/gymtorch
# Using /root/.cache/torch_extensions/py38_cu117 as PyTorch extensions root...
# Creating extension directory /root/.cache/torch_extensions/py38_cu117/gymtorch...
# Emitting ninja build file /root/.cache/torch_extensions/py38_cu117/gymtorch/build.ninja...
# Building extension module gymtorch...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ...

# %%
# %env OPENAI_API_KEY=***REMOVED***
# Out:
# env: OPENAI_API_KEY=***REMOVED***

# %%
! cd /notebooks/Eureka/eureka && micromamba run -n eureka python eureka.py env=shadow_hand sample=16 iteration=5 model=gpt-3.5-turbo
# Out:
# warning  libmamba 'root_prefix' set with default value: /root/micromamba
# [2024-07-03 12:08:56,070][root][INFO] - Workspace: /notebooks/Eureka/eureka/outputs/eureka/2024-07-03_12-08-56
# [2024-07-03 12:08:56,071][root][INFO] - Project Root: /notebooks/Eureka/eureka
# [2024-07-03 12:08:56,071][root][INFO] - Using LLM: gpt-3.5-turbo
# [2024-07-03 12:08:56,071][root][INFO] - Task: ShadowHand
# [2024-07-03 12:08:56,071][root][INFO] - Task description: to make the shadow hand spin the object to a target orientation
# [2024-07-03 12:08:56,186][root][INFO] - Iteration 0: Generating 16 samples with gpt-3.5-turbo
# [2024-07-03 12:09:01,455][root][INFO] - Iteration 0: Prompt Tokens: 1735, Completion Tokens: 2570, Total Tokens: 4305
# [2024-07-03 12:09:01,455][root][INFO] - Iteration 0: Processing Code Run 0
# [2024-07-03 12:09:21,470][root][INFO] - Iteration 0: Code Run 0 execution error!
# [2024-07-03 12:09:21,470][root][INFO] - Iteration 0: Processing Code Run 1
# ...

# %%
! cd /notebooks/Eureka/eureka && micromamba run -n eureka python eureka.py env=shadow_hand sample=16 iteration=5 model=gpt-3.5-turbo
